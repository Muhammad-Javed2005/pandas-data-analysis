# %% [markdown]
# # ***Engr.Muhammad Javed***

# %%
import pandas as pd

data = pd.read_excel('files/employee.xlsx')
data
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 2        3    1203     Officer          HR  28.0       NaN
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant         NaN  34.0  100000.0
# 6        7    1111  Accountant    Accounts   NaN  110000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 8        9    1234     Manager          IT  23.0       NaN
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# ...

# %%
# average salary by department
data.groupby("Department")["Salary"].mean()
# Out:
# Department
# Account       123000.0
# Accounts      100000.0
# HR            120000.0
# IT             86250.0
# Production     91750.0
# Name: Salary, dtype: float64

# %%
# designation wise employee count
data.groupby("Designation")["Department"].count()
# Out:
# Designation
# Accountant    2
# Engineer      3
# Manager       3
# Office Boy    2
# Officer       6
# Name: Department, dtype: int64

# %%
df2 = pd.read_excel("files/employee.xlsx")
# Add new column experience level

# using list comprehension
# df2["Experience_level"] = ["Senior" if (age>=40) else "Junior" for age in df2["Age"]]

# using lambda function
df2["Experience_level"] = df2["Age"].apply(lambda x: "Senior" if x>=40 else "Junior")

df2
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary Experience_level
# 0        1    1101     Manager    Accounts  50.0  200000.0           Senior
# 1        2    1107     Officer          IT  30.0   80000.0           Junior
# 2        3    1203     Officer          HR  28.0       NaN           Junior
# 3        4    1005     Manager          HR  45.0  120000.0           Senior
# 4        5    2123  Office Boy    Accounts  27.0   45000.0           Junior
# 5        6    2451  Accountant         NaN  34.0  100000.0           Junior
# 6        7    1111  Accountant    Accounts   NaN  110000.0           Junior
# 7        8    1001     Officer          IT  25.0   75000.0           Junior
# 8        9    1234     Manager          IT  23.0       NaN           Junior
# 9       10    2156    Engineer  Production  45.0   89000.0           Senior
# 10      11    6543     Officer  Production  29.0  100000.0           Junior
# ...

# %%
# list of employees in IT and Age >= 40

# using boolean indexing
df2[(df2["Age"]<=40) & (df2["Department"] == "IT")]

# using query
df2.query("Department == 'IT' and Age <= 40")
# Out:
#     Serial  Emp_ID Designation Department   Age    Salary Experience_level
# 1        2    1107     Officer         IT  30.0   80000.0           Junior
# 7        8    1001     Officer         IT  25.0   75000.0           Junior
# 8        9    1234     Manager         IT  23.0       NaN           Junior
# 13      14    1098     Officer         IT  25.0  100000.0           Junior
# 14      15    2912     Officer         IT  31.0   90000.0           Junior

# %%
# histogram in python
df2["Salary"].hist()
# Out:
# <Axes: >

# %%
print(data.iloc[:3,:3])  # first three rows and first three columns

print(data.iloc[2:5, 2:6]) # random three rows and four columns
# Out:
#    Serial  Emp_ID Designation
# 0       1    1101     Manager
# 1       2    1107     Officer
# 2       3    1203     Officer
#   Designation Department   Age    Salary
# 2     Officer         HR  28.0       NaN
# 3     Manager         HR  45.0  120000.0
# 4  Office Boy   Accounts  27.0   45000.0

# %%
# display employee_id, department and salary of employees whose age > 40
data.loc[data["Age"] > 40, ["Emp_ID", "Department", "Salary"]]
# first parameter is for rows, and second param is for column names
# Out:
#     Emp_ID  Department    Salary
# 0     1101    Accounts  200000.0
# 3     1005          HR  120000.0
# 9     2156  Production   89000.0
# 11    3214     Account  123000.0
# 12    2156  Production   89000.0
# 16    2156  Production   89000.0

# %%
# deleting column from dataframe permanently
data.drop(columns="Serial", inplace=True)
data
# Out:
#     Emp_ID Designation  Department   Age    Salary
# 0     1101     Manager    Accounts  50.0  200000.0
# 1     1107     Officer          IT  30.0   80000.0
# 2     1203     Officer          HR  28.0       NaN
# 3     1005     Manager          HR  45.0  120000.0
# 4     2123  Office Boy    Accounts  27.0   45000.0
# 5     2451  Accountant         NaN  34.0  100000.0
# 6     1111  Accountant    Accounts   NaN  110000.0
# 7     1001     Officer          IT  25.0   75000.0
# 8     1234     Manager          IT  23.0       NaN
# 9     2156    Engineer  Production  45.0   89000.0
# 10    6543     Officer  Production  29.0  100000.0
# 11    3214  Accountant     Account  49.0  123000.0
# 12    2156    Engineer  Production  45.0   89000.0
# 13    1098     Officer          IT  25.0  100000.0
# 14    2912     Officer          IT  31.0   90000.0
# 15    1222     Officer         NaN  25.0       NaN
# 16    2156    Engineer  Production  45.0   89000.0
# ...

# %%
# renaming Emp_ID column
data.rename(columns={"Emp_ID":"Employee_ID"}, inplace=True)
data
# Out:
#     Employee_ID Designation  Department   Age    Salary
# 0          1101     Manager    Accounts  50.0  200000.0
# 1          1107     Officer          IT  30.0   80000.0
# 2          1203     Officer          HR  28.0       NaN
# 3          1005     Manager          HR  45.0  120000.0
# 4          2123  Office Boy    Accounts  27.0   45000.0
# 5          2451  Accountant         NaN  34.0  100000.0
# 6          1111  Accountant    Accounts   NaN  110000.0
# 7          1001     Officer          IT  25.0   75000.0
# 8          1234     Manager          IT  23.0       NaN
# 9          2156    Engineer  Production  45.0   89000.0
# 10         6543     Officer  Production  29.0  100000.0
# 11         3214  Accountant     Account  49.0  123000.0
# 12         2156    Engineer  Production  45.0   89000.0
# 13         1098     Officer          IT  25.0  100000.0
# 14         2912     Officer          IT  31.0   90000.0
# 15         1222     Officer         NaN  25.0       NaN
# ...

# %%
data[data.Designation == ("MANAger").capitalize()]
# Out:
#    Employee_ID Designation Department   Age    Salary
# 0         1101     Manager   Accounts  50.0  200000.0
# 3         1005     Manager         HR  45.0  120000.0
# 8         1234     Manager         IT  23.0       NaN

# %%
# check if a department name contains acc

df2.fillna({"Department": df2.Department.mode()[0]},inplace=True)
df2[df2.Department.str.contains("acc",case=False)]
# Out:
#     Serial  Emp_ID Designation Department   Age    Salary Experience_level
# 0        1    1101     Manager   Accounts  50.0  200000.0           Senior
# 4        5    2123  Office Boy   Accounts  27.0   45000.0           Junior
# 6        7    1111  Accountant   Accounts   NaN  110000.0           Junior
# 11      12    3214  Accountant    Account  49.0  123000.0           Senior
# 17      18    2123  Office Boy   Accounts  27.0   45000.0           Junior

# %%
data[data.duplicated()]
# Out:
#     Employee_ID Designation  Department   Age   Salary
# 12         2156    Engineer  Production  45.0  89000.0
# 16         2156    Engineer  Production  45.0  89000.0
# 17         2123  Office Boy    Accounts  27.0  45000.0

# %%
data
# Out:
#     Employee_ID Designation  Department   Age    Salary
# 0          1101     Manager    Accounts  50.0  200000.0
# 1          1107     Officer          IT  30.0   80000.0
# 2          1203     Officer          HR  28.0       NaN
# 3          1005     Manager          HR  45.0  120000.0
# 4          2123  Office Boy    Accounts  27.0   45000.0
# 5          2451  Accountant         NaN  34.0  100000.0
# 6          1111  Accountant    Accounts   NaN  110000.0
# 7          1001     Officer          IT  25.0   75000.0
# 8          1234     Manager          IT  23.0       NaN
# 9          2156    Engineer  Production  45.0   89000.0
# 10         6543     Officer  Production  29.0  100000.0
# 11         3214  Accountant     Account  49.0  123000.0
# 12         2156    Engineer  Production  45.0   89000.0
# 13         1098     Officer          IT  25.0  100000.0
# 14         2912     Officer          IT  31.0   90000.0
# 15         1222     Officer         NaN  25.0       NaN
# ...

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#     Employee_ID Designation  Department   Age    Salary
# 0          1101     Manager    Accounts  50.0  200000.0
# 1          1107     Officer          IT  30.0   80000.0
# 2          1203     Officer          HR  28.0       NaN
# 3          1005     Manager          HR  45.0  120000.0
# 4          2123  Office Boy    Accounts  27.0   45000.0
# 5          2451  Accountant         NaN  34.0  100000.0
# 6          1111  Accountant    Accounts   NaN  110000.0
# 7          1001     Officer          IT  25.0   75000.0
# 8          1234     Manager          IT  23.0       NaN
# 9          2156    Engineer  Production  45.0   89000.0
# 10         6543     Officer  Production  29.0  100000.0
# 11         3214  Accountant     Account  49.0  123000.0
# 13         1098     Officer          IT  25.0  100000.0
# 14         2912     Officer          IT  31.0   90000.0
# 15         1222     Officer         NaN  25.0       NaN

# %%
# saving data in csv file
data.to_excel("cleaned_data.xlsx",index=False)

# %% [markdown]
# ### **Exercise**
# - Add a new Column Revised_Salary, revised salary is 10% more than actual salary
# - Then calculate total additional cost to company
# - Which department faces the biggest impact

# %%
# 1. Add a new Column Revised_Salary, revised salary is 10% more than actual salary
data["Revised_Salary"] = [salary+0.1*salary for salary in data["Salary"]]
data
# Out:
#     Employee_ID Designation  Department   Age    Salary  Revised_Salary
# 0          1101     Manager    Accounts  50.0  200000.0        220000.0
# 1          1107     Officer          IT  30.0   80000.0         88000.0
# 2          1203     Officer          HR  28.0       NaN             NaN
# 3          1005     Manager          HR  45.0  120000.0        132000.0
# 4          2123  Office Boy    Accounts  27.0   45000.0         49500.0
# 5          2451  Accountant         NaN  34.0  100000.0        110000.0
# 6          1111  Accountant    Accounts   NaN  110000.0        121000.0
# 7          1001     Officer          IT  25.0   75000.0         82500.0
# 8          1234     Manager          IT  23.0       NaN             NaN
# 9          2156    Engineer  Production  45.0   89000.0         97900.0
# 10         6543     Officer  Production  29.0  100000.0        110000.0
# 11         3214  Accountant     Account  49.0  123000.0        135300.0
# ...

# %%
# 2. Calculate total additional cost to company
add_cost_to_company=data.groupby("Department")["Revised_Salary"].sum()-data.groupby("Department")["Salary"].sum()
print("Additinal Cost to company department wise:\n",add_cost_to_company)
print(f"\nTotal additional cost to company: {add_cost_to_company.sum()}")
# Out:
# Additinal Cost to company department wise:
#  Department
# Account       12300.0
# Accounts      35500.0
# HR            12000.0
# IT            34500.0
# Production    18900.0
# dtype: float64
#
# Total additional cost to company: 113200.0

# %%
# 2. Which Department faces the biggest impact
biggest_impact = data.groupby("Department")["Revised_Salary"].sum()-data.groupby("Department")["Salary"].sum()
biggest_impact_id = biggest_impact.idxmax()
biggest_impact_value = biggest_impact.max()
print(f"The department facing the biggest impact is {biggest_impact_id} with an addtional cost of {biggest_impact_value}")
# Out:
# The department facing the biggest impact is Accounts with an addtional cost of 35500.0
